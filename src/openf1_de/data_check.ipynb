# %%
from pathlib import Path
import pandas as pd

# %%
path = Path("../../data/bronze/sessions/2026.parquet")
df = pd.read_parquet(path)

# %%
df
# Out:
#      session_key session_type session_name                 date_start  \
# 0          11465     Practice        Day 1  2026-02-11T07:00:00+00:00
# 1          11466     Practice        Day 2  2026-02-12T07:00:00+00:00
# 2          11467     Practice        Day 3  2026-02-13T07:00:00+00:00
# 3          11470     Practice        Day 1  2026-02-18T07:00:00+00:00
# 4          11469     Practice        Day 2  2026-02-19T07:00:00+00:00
# ..           ...          ...          ...                        ...
# 121        11429     Practice   Practice 1  2026-12-04T09:30:00+00:00
# 122        11430     Practice   Practice 2  2026-12-04T13:00:00+00:00
# 123        11431     Practice   Practice 3  2026-12-05T10:30:00+00:00
# 124        11432   Qualifying   Qualifying  2026-12-05T14:00:00+00:00
# 125        11436         Race         Race  2026-12-06T13:00:00+00:00
#
#                       date_end  meeting_key  circuit_key  circuit_short_name  \
# ...
