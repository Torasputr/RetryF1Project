# %%
from pathlib import Path
import pandas as pd

# %%
BASE_PATH = "../../data/bronze"

path_s = Path("../../data/bronze/sessions/2026.parquet")
df_s = pd.read_parquet(path_s)
path_m = Path("../../data/bronze/meetings/2026.parquet")
df_m = pd.read_parquet(path_m)
path_d = Path("../../data/bronze/drivers/2026.parquet")
df_d = pd.read_parquet(path_d)
path_sr = Path(f"{BASE_PATH}/session_results/2026.parquet")
df_sr = pd.read_parquet(path_sr)

# %%
df_sr
# Out:
#      position  driver_number  number_of_laps    dnf    dns    dsq  \
# 0         1.0              1            58.0  False  False  False
# 1         2.0              3           136.0  False  False  False
# 2         3.0             16            80.0  False  False  False
# 3         4.0             31           115.0  False  False  False
# 4         5.0             81            54.0  False  False  False
# ..        ...            ...             ...    ...    ...    ...
# 668       NaN              1            38.0   True  False  False
# 669       NaN             63            29.0   True  False  False
# 670       NaN             14            23.0   True  False  False
# 671       NaN             23            11.0   True  False  False
# 672       NaN             41             0.0  False   True  False
#
#     gap_to_leader  meeting_key  session_key duration  \
# 0             0.0         1304        11465   94.669
# 1           0.129         1304        11465   94.798
# ...
