# %%
from pathlib import Path
import pandas as pd

# %%
path = Path("../../data/bronze/meetings/2026.parquet")
df = pd.read_parquet(path)

# %%
df
# Out:
#     meeting_key              meeting_name  \
# 0          1304        Pre-Season Testing
# 1          1305        Pre-Season Testing
# 2          1279     Australian Grand Prix
# 3          1280        Chinese Grand Prix
# 4          1281       Japanese Grand Prix
# 5          1282        Bahrain Grand Prix
# 6          1283  Saudi Arabian Grand Prix
# 7          1284          Miami Grand Prix
# 8          1285       Canadian Grand Prix
# 9          1286         Monaco Grand Prix
# 10         1287      Barcelona Grand Prix
# 11         1288       Austrian Grand Prix
# 12         1289        British Grand Prix
# 13         1290        Belgian Grand Prix
# 14         1291      Hungarian Grand Prix
# 15         1292          Dutch Grand Prix
# 16         1293        Italian Grand Prix
# 17         1294        Spanish Grand Prix
# 18         1295     Azerbaijan Grand Prix
# 19         1296      Singapore Grand Prix
# 20         1297  United States Grand Prix
# ...
